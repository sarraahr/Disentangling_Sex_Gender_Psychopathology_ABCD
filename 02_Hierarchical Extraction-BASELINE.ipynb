# %%
# %load_ext autoreload
# %autoreload 2
from helper import *
# %config InlineBackend.figure_format='retina'

# %%
alldata = abcd_data()
alldata_1 = get_data_with_followups(alldata, followups = '1y_follow_up')
abcd_baseline = abcd_data(measurement = 'baseline', load = False, df = alldata_1)
baseline_clean = prepare_data(abcd_baseline)
item_list = filter_polychoric_corr(baseline_clean, print_corr = False)

# %%
aggregate_dict = {"cbcl_q8182_steals": ['cbcl_q81_p', 'cbcl_q82_p'], 
                  "cbcl_q165797_attacks/threatens/bullies": ['cbcl_q57_p', 'cbcl_q16_p', 'cbcl_q97_p'],
                  "cbcl_q56cf_stomach_issues":['cbcl_q56c_p', 'cbcl_q56f_p'],
                  "cbcl_q5355_weight_problems":['cbcl_q53_p', 'cbcl_q55_p'],
                  "cbcl_q4070_hallucinaitons": ['cbcl_q70_p', 'cbcl_q40_p'],
                  "cbcl_q2548_peer_problems": ['cbcl_q25_p', 'cbcl_q48_p'],
                  "cbcl_q222328_disobeys_rules": ['cbcl_q28_p', 'cbcl_q23_p', 'cbcl_q22_p'],
                  "cbcl_q21106_destroys": ['cbcl_q20_p', 'cbcl_q106_p', 'cbcl_q21_p'],
                  "cbcl_q081078_distracted/hyperactive": ['cbcl_q10_p', 'cbcl_q78_p', 'cbcl_q08_p']}

baseline_data = aggregate_items(baseline_clean, item_list, aggregate_dict)
baseline_polycorr = common.polychoric.polychoric_correlation_serial(get_question_items(baseline_data, 'cbcl_q').to_numpy().T,0,3)

# %%
abcd = abcd_dict("abcd_cbcl01")

# %%
# 1 factor, general p factor 
factor_scores1,loadings_1 = get_EFA_structure(baseline_data, 1, 'varimax', run_again = False)

loadings_1.rename(index=abcd, inplace=True)
loadings_1.sort_values(by = 0,ascending=False, inplace= True)
loadings_1.round(4).style.applymap(color)

# %%
# 2 factors: Externalizing & Internalizing
factor_scores2, loadings_2 = get_EFA_structure(baseline_data, 2, 'varimax', run_again = False)
loadings_2.rename(index=abcd, inplace=True)
styler2_1 = pd.DataFrame(loadings_2[0])
styler2_1.sort_values(by = 0,ascending=False, inplace= True)
styler2_1.round(4).style.applymap(color) # Broad Externalizing

styler2_2 = pd.DataFrame(loadings_2[1])
styler2_2.sort_values(by = 1,ascending=False, inplace= True)
styler2_2.round(4).style.applymap(color) # Broad Internalizing
# Out:
# <style type="text/css">
# #T_8259f_row0_col0, #T_8259f_row1_col0, #T_8259f_row2_col0, #T_8259f_row3_col0, #T_8259f_row4_col0, #T_8259f_row5_col0, #T_8259f_row6_col0 {
#   background-color: #2ecc71;
# }
# #T_8259f_row7_col0, #T_8259f_row8_col0, #T_8259f_row9_col0, #T_8259f_row10_col0, #T_8259f_row11_col0, #T_8259f_row12_col0, #T_8259f_row13_col0, #T_8259f_row14_col0, #T_8259f_row15_col0, #T_8259f_row16_col0, #T_8259f_row17_col0, #T_8259f_row18_col0, #T_8259f_row19_col0, #T_8259f_row20_col0, #T_8259f_row21_col0, #T_8259f_row22_col0, #T_8259f_row23_col0, #T_8259f_row24_col0, #T_8259f_row25_col0, #T_8259f_row26_col0, #T_8259f_row27_col0, #T_8259f_row28_col0, #T_8259f_row29_col0, #T_8259f_row30_col0, #T_8259f_row31_col0, #T_8259f_row32_col0, #T_8259f_row33_col0, #T_8259f_row34_col0, #T_8259f_row35_col0 {
#   background-color: #f1c40f;
# }
# #T_8259f_row36_col0, #T_8259f_row37_col0, #T_8259f_row38_col0, #T_8259f_row39_col0, #T_8259f_row40_col0, #T_8259f_row41_col0, #T_8259f_row42_col0, #T_8259f_row43_col0, #T_8259f_row44_col0, #T_8259f_row45_col0, #T_8259f_row46_col0, #T_8259f_row47_col0, #T_8259f_row48_col0, #T_8259f_row49_col0, #T_8259f_row50_col0, #T_8259f_row51_col0, #T_8259f_row52_col0, #T_8259f_row53_col0, #T_8259f_row54_col0, #T_8259f_row55_col0, #T_8259f_row56_col0, #T_8259f_row57_col0, #T_8259f_row58_col0, #T_8259f_row59_col0, #T_8259f_row60_col0, #T_8259f_row61_col0, #T_8259f_row62_col0, #T_8259f_row63_col0, #T_8259f_row64_col0, #T_8259f_row65_col0, #T_8259f_row66_col0, #T_8259f_row67_col0, #T_8259f_row68_col0, #T_8259f_row69_col0, #T_8259f_row70_col0, #T_8259f_row71_col0, #T_8259f_row72_col0, #T_8259f_row73_col0, #T_8259f_row74_col0, #T_8259f_row75_col0, #T_8259f_row76_col0, #T_8259f_row77_col0, #T_8259f_row78_col0, #T_8259f_row79_col0, #T_8259f_row80_col0, #T_8259f_row81_col0, #T_8259f_row82_col0, #T_8259f_row83_col0, #T_8259f_row84_col0, #T_8259f_row85_col0, #T_8259f_row86_col0, #T_8259f_row87_col0, #T_8259f_row88_col0, #T_8259f_row89_col0, #T_8259f_row90_col0, #T_8259f_row91_col0, #T_8259f_row92_col0, #T_8259f_row93_col0, #T_8259f_row94_col0, #T_8259f_row95_col0, #T_8259f_row96_col0, #T_8259f_row97_col0, #T_8259f_row98_col0, #T_8259f_row99_col0, #T_8259f_row100_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_8259f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8259f_level0_col0" class="col_heading level0 col0" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8259f_level0_row0" class="row_heading level0 row0" >Worries</th>
#       <td id="T_8259f_row0_col0" class="data row0 col0" >0.638700</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row1" class="row_heading level0 row1" >Too fearful or anxious</th>
#       <td id="T_8259f_row1_col0" class="data row1 col0" >0.638600</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row2" class="row_heading level0 row2" >Self-conscious or easily embarrassed</th>
#       <td id="T_8259f_row2_col0" class="data row2 col0" >0.579200</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row3" class="row_heading level0 row3" >Nervous, highstrung, or tense</th>
#       <td id="T_8259f_row3_col0" class="data row3 col0" >0.555000</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row4" class="row_heading level0 row4" >Unhappy, sad, or depressed</th>
#       <td id="T_8259f_row4_col0" class="data row4 col0" >0.533300</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row5" class="row_heading level0 row5" >Feels worthless or inferior</th>
#       <td id="T_8259f_row5_col0" class="data row5 col0" >0.527400</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row6" class="row_heading level0 row6" >Feels too guilty</th>
#       <td id="T_8259f_row6_col0" class="data row6 col0" >0.508100</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row7" class="row_heading level0 row7" >Too shy or timid</th>
#       <td id="T_8259f_row7_col0" class="data row7 col0" >0.488200</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row8" class="row_heading level0 row8" >Feels they have to be perfect</th>
#       <td id="T_8259f_row8_col0" class="data row8 col0" >0.479200</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row9" class="row_heading level0 row9" >Complains of loneliness</th>
#       <td id="T_8259f_row9_col0" class="data row9 col0" >0.468900</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row10" class="row_heading level0 row10" >Withdrawn, doesn't get involved with others</th>
#       <td id="T_8259f_row10_col0" class="data row10 col0" >0.459400</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row11" class="row_heading level0 row11" >Fears they might think or do something bad</th>
#       <td id="T_8259f_row11_col0" class="data row11 col0" >0.458300</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row12" class="row_heading level0 row12" >Can't get their mind off certain thoughts; obsessions</th>
#       <td id="T_8259f_row12_col0" class="data row12 col0" >0.455200</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row13" class="row_heading level0 row13" >Sulks a lot</th>
#       <td id="T_8259f_row13_col0" class="data row13 col0" >0.442500</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row14" class="row_heading level0 row14" >Sudden changes in mood or feelings</th>
#       <td id="T_8259f_row14_col0" class="data row14 col0" >0.442400</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row15" class="row_heading level0 row15" >Fears certain animals, situations, or places, other than school</th>
#       <td id="T_8259f_row15_col0" class="data row15 col0" >0.436800</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row16" class="row_heading level0 row16" >Clings to adults or too dependent</th>
#       <td id="T_8259f_row16_col0" class="data row16 col0" >0.429900</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row17" class="row_heading level0 row17" >cbcl_q56cf_stomach_issues</th>
#       <td id="T_8259f_row17_col0" class="data row17 col0" >0.429100</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row18" class="row_heading level0 row18" >Feels or complains that no one loves them</th>
#       <td id="T_8259f_row18_col0" class="data row18 col0" >0.423000</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row19" class="row_heading level0 row19" >Underactive, slow moving, or lacks energy</th>
#       <td id="T_8259f_row19_col0" class="data row19 col0" >0.418500</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row20" class="row_heading level0 row20" >Trouble sleeping</th>
#       <td id="T_8259f_row20_col0" class="data row20 col0" >0.414400</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row21" class="row_heading level0 row21" >Would rather be alone than with others</th>
#       <td id="T_8259f_row21_col0" class="data row21 col0" >0.413600</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row22" class="row_heading level0 row22" >Fears going to school</th>
#       <td id="T_8259f_row22_col0" class="data row22 col0" >0.409300</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row23" class="row_heading level0 row23" >Cries a lot</th>
#       <td id="T_8259f_row23_col0" class="data row23 col0" >0.389600</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row24" class="row_heading level0 row24" >Overtired without good reason</th>
#       <td id="T_8259f_row24_col0" class="data row24 col0" >0.387500</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row25" class="row_heading level0 row25" >Confused or seems to be in a fog</th>
#       <td id="T_8259f_row25_col0" class="data row25 col0" >0.384100</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row26" class="row_heading level0 row26" >Daydreams or gets lost in their thoughts</th>
#       <td id="T_8259f_row26_col0" class="data row26 col0" >0.380800</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row27" class="row_heading level0 row27" >Stares blankly</th>
#       <td id="T_8259f_row27_col0" class="data row27 col0" >0.373000</td>
#     </tr>
#     <tr>
#       <th id="T_8259f_level0_row28" class="row_heading level0 row28" >Refuses to

# %%
# 3 factors
factor_scores3, loadings_3 = get_EFA_structure(baseline_data, 3, 'varimax', run_again = False)
loadings_3.rename(index=abcd, inplace=True)
styler3_1 = pd.DataFrame(loadings_3[0])
styler3_1.sort_values(by = 0,ascending=False, inplace= True)
styler3_1.round(4).style.applymap(color) # Neurodevelopmental

styler3_2 = pd.DataFrame(loadings_3[1])
styler3_2.sort_values(by = 1,ascending=False, inplace= True)
styler3_2.round(4).style.applymap(color) #  Broad Internalizing

styler3_3 = pd.DataFrame(loadings_3[2])
styler3_3.sort_values(by = 2,ascending=False, inplace= True)
styler3_3.round(4).style.applymap(color) # Broad Externalizing
# Out:
# <style type="text/css">
# #T_9ab4d_row0_col0, #T_9ab4d_row1_col0, #T_9ab4d_row2_col0, #T_9ab4d_row3_col0, #T_9ab4d_row4_col0, #T_9ab4d_row5_col0, #T_9ab4d_row6_col0, #T_9ab4d_row7_col0, #T_9ab4d_row8_col0, #T_9ab4d_row9_col0, #T_9ab4d_row10_col0 {
#   background-color: #2ecc71;
# }
# #T_9ab4d_row11_col0, #T_9ab4d_row12_col0, #T_9ab4d_row13_col0, #T_9ab4d_row14_col0, #T_9ab4d_row15_col0, #T_9ab4d_row16_col0, #T_9ab4d_row17_col0, #T_9ab4d_row18_col0, #T_9ab4d_row19_col0, #T_9ab4d_row20_col0, #T_9ab4d_row21_col0, #T_9ab4d_row22_col0, #T_9ab4d_row23_col0, #T_9ab4d_row24_col0, #T_9ab4d_row25_col0 {
#   background-color: #f1c40f;
# }
# #T_9ab4d_row26_col0, #T_9ab4d_row27_col0, #T_9ab4d_row28_col0, #T_9ab4d_row29_col0, #T_9ab4d_row30_col0, #T_9ab4d_row31_col0, #T_9ab4d_row32_col0, #T_9ab4d_row33_col0, #T_9ab4d_row34_col0, #T_9ab4d_row35_col0, #T_9ab4d_row36_col0, #T_9ab4d_row37_col0, #T_9ab4d_row38_col0, #T_9ab4d_row39_col0, #T_9ab4d_row40_col0, #T_9ab4d_row41_col0, #T_9ab4d_row42_col0, #T_9ab4d_row43_col0, #T_9ab4d_row44_col0, #T_9ab4d_row45_col0, #T_9ab4d_row46_col0, #T_9ab4d_row47_col0, #T_9ab4d_row48_col0, #T_9ab4d_row49_col0, #T_9ab4d_row50_col0, #T_9ab4d_row51_col0, #T_9ab4d_row52_col0, #T_9ab4d_row53_col0, #T_9ab4d_row54_col0, #T_9ab4d_row55_col0, #T_9ab4d_row56_col0, #T_9ab4d_row57_col0, #T_9ab4d_row58_col0, #T_9ab4d_row59_col0, #T_9ab4d_row60_col0, #T_9ab4d_row61_col0, #T_9ab4d_row62_col0, #T_9ab4d_row63_col0, #T_9ab4d_row64_col0, #T_9ab4d_row65_col0, #T_9ab4d_row66_col0, #T_9ab4d_row67_col0, #T_9ab4d_row68_col0, #T_9ab4d_row69_col0, #T_9ab4d_row70_col0, #T_9ab4d_row71_col0, #T_9ab4d_row72_col0, #T_9ab4d_row73_col0, #T_9ab4d_row74_col0, #T_9ab4d_row75_col0, #T_9ab4d_row76_col0, #T_9ab4d_row77_col0, #T_9ab4d_row78_col0, #T_9ab4d_row79_col0, #T_9ab4d_row80_col0, #T_9ab4d_row81_col0, #T_9ab4d_row82_col0, #T_9ab4d_row83_col0, #T_9ab4d_row84_col0, #T_9ab4d_row85_col0, #T_9ab4d_row86_col0, #T_9ab4d_row87_col0, #T_9ab4d_row88_col0, #T_9ab4d_row89_col0, #T_9ab4d_row90_col0, #T_9ab4d_row91_col0, #T_9ab4d_row92_col0, #T_9ab4d_row93_col0, #T_9ab4d_row94_col0, #T_9ab4d_row95_col0, #T_9ab4d_row96_col0, #T_9ab4d_row97_col0, #T_9ab4d_row98_col0, #T_9ab4d_row99_col0, #T_9ab4d_row100_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_9ab4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ab4d_level0_col0" class="col_heading level0 col0" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab4d_level0_row0" class="row_heading level0 row0" >cbcl_q222328_disobeys_rules</th>
#       <td id="T_9ab4d_row0_col0" class="data row0 col0" >0.626300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row1" class="row_heading level0 row1" >cbcl_q165797_attacks/threatens/bullies</th>
#       <td id="T_9ab4d_row1_col0" class="data row1 col0" >0.619900</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row2" class="row_heading level0 row2" >Temper tantrums or hot temper</th>
#       <td id="T_9ab4d_row2_col0" class="data row2 col0" >0.585100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row3" class="row_heading level0 row3" >Argues a lot</th>
#       <td id="T_9ab4d_row3_col0" class="data row3 col0" >0.561700</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row4" class="row_heading level0 row4" >Screams a lot</th>
#       <td id="T_9ab4d_row4_col0" class="data row4 col0" >0.552100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row5" class="row_heading level0 row5" >cbcl_q21106_destroys</th>
#       <td id="T_9ab4d_row5_col0" class="data row5 col0" >0.545100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row6" class="row_heading level0 row6" >Gets in many fights</th>
#       <td id="T_9ab4d_row6_col0" class="data row6 col0" >0.540400</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row7" class="row_heading level0 row7" >Doesn't seem to feel guilty after misbehaving</th>
#       <td id="T_9ab4d_row7_col0" class="data row7 col0" >0.523500</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row8" class="row_heading level0 row8" >Lying or cheating</th>
#       <td id="T_9ab4d_row8_col0" class="data row8 col0" >0.519900</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row9" class="row_heading level0 row9" >Teases a lot</th>
#       <td id="T_9ab4d_row9_col0" class="data row9 col0" >0.511600</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row10" class="row_heading level0 row10" >Stubborn, sullen, or irritable</th>
#       <td id="T_9ab4d_row10_col0" class="data row10 col0" >0.504300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row11" class="row_heading level0 row11" >Swearing or obscene language</th>
#       <td id="T_9ab4d_row11_col0" class="data row11 col0" >0.497300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row12" class="row_heading level0 row12" >Impulsive or acts without thinking</th>
#       <td id="T_9ab4d_row12_col0" class="data row12 col0" >0.485800</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row13" class="row_heading level0 row13" >Sudden changes in mood or feelings</th>
#       <td id="T_9ab4d_row13_col0" class="data row13 col0" >0.475300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row14" class="row_heading level0 row14" >Demands a lot of attention</th>
#       <td id="T_9ab4d_row14_col0" class="data row14 col0" >0.469100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row15" class="row_heading level0 row15" >Easily jealous</th>
#       <td id="T_9ab4d_row15_col0" class="data row15 col0" >0.460500</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row16" class="row_heading level0 row16" >Showing off or clowning</th>
#       <td id="T_9ab4d_row16_col0" class="data row16 col0" >0.421900</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row17" class="row_heading level0 row17" >Feels or complains that no one loves them</th>
#       <td id="T_9ab4d_row17_col0" class="data row17 col0" >0.420300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row18" class="row_heading level0 row18" >cbcl_q2548_peer_problems</th>
#       <td id="T_9ab4d_row18_col0" class="data row18 col0" >0.415300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row19" class="row_heading level0 row19" >cbcl_q8182_steals</th>
#       <td id="T_9ab4d_row19_col0" class="data row19 col0" >0.396600</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row20" class="row_heading level0 row20" >Bragging, boasting </th>
#       <td id="T_9ab4d_row20_col0" class="data row20 col0" >0.395800</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row21" class="row_heading level0 row21" >Unusually loud</th>
#       <td id="T_9ab4d_row21_col0" class="data row21 col0" >0.392100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row22" class="row_heading level0 row22" >Suspicious</th>
#       <td id="T_9ab4d_row22_col0" class="data row22 col0" >0.385500</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row23" class="row_heading level0 row23" >Sulks a lot</th>
#       <td id="T_9ab4d_row23_col0" class="data row23 col0" >0.383400</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row24" class="row_heading level0 row24" >Feels others are out to get them</th>
#       <td id="T_9ab4d_row24_col0" class="data row24 col0" >0.374100</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row25" class="row_heading level0 row25" >Hangs around with others who get in trouble</th>
#       <td id="T_9ab4d_row25_col0" class="data row25 col0" >0.366600</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row26" class="row_heading level0 row26" >Whining</th>
#       <td id="T_9ab4d_row26_col0" class="data row26 col0" >0.334600</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row27" class="row_heading level0 row27" >Cruel to animals</th>
#       <td id="T_9ab4d_row27_col0" class="data row27 col0" >0.303300</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row28" class="row_heading level0 row28" >Unhappy, sad, or depressed</th>
#       <td id="T_9ab4d_row28_col0" class="data row28 col0" >0.300700</td>
#     </tr>
#     <tr>
#       <th id="T_9ab4d_level0_row29" class="row_he

# %%
# 4 factors
factor_scores4, loadings_4 = get_EFA_structure(baseline_data, 4, 'varimax', run_again = False)
loadings_4.rename(index=abcd, inplace=True)
styler4_1 = pd.DataFrame(loadings_4[0])
styler4_1.sort_values(by = 0,ascending=False, inplace= True)
styler4_1.round(4).style.applymap(color) # Externalizing (Antagonistic) 

styler4_2 = pd.DataFrame(loadings_4[1])
styler4_2.sort_values(by = 1,ascending=False, inplace= True)
styler4_2.round(4).style.applymap(color) # Internalizing

styler4_3 = pd.DataFrame(loadings_4[2])
styler4_3.sort_values(by = 2,ascending=False, inplace= True)
styler4_3.round(4).style.applymap(color) # Neurodevelopmental

styler4_4 = pd.DataFrame(loadings_4[3])
styler4_4.sort_values(by = 3,ascending=False, inplace= True)
styler4_4.round(4).style.applymap(color) # Externalizing (Disinhibited)
# Out:
# <style type="text/css">
# #T_0245b_row0_col0, #T_0245b_row1_col0, #T_0245b_row2_col0 {
#   background-color: #2ecc71;
# }
# #T_0245b_row3_col0, #T_0245b_row4_col0, #T_0245b_row5_col0, #T_0245b_row6_col0, #T_0245b_row7_col0, #T_0245b_row8_col0, #T_0245b_row9_col0, #T_0245b_row10_col0, #T_0245b_row11_col0, #T_0245b_row12_col0, #T_0245b_row13_col0, #T_0245b_row14_col0, #T_0245b_row15_col0, #T_0245b_row16_col0, #T_0245b_row17_col0, #T_0245b_row18_col0 {
#   background-color: #f1c40f;
# }
# #T_0245b_row19_col0, #T_0245b_row20_col0, #T_0245b_row21_col0, #T_0245b_row22_col0, #T_0245b_row23_col0, #T_0245b_row24_col0, #T_0245b_row25_col0, #T_0245b_row26_col0, #T_0245b_row27_col0, #T_0245b_row28_col0, #T_0245b_row29_col0, #T_0245b_row30_col0, #T_0245b_row31_col0, #T_0245b_row32_col0, #T_0245b_row33_col0, #T_0245b_row34_col0, #T_0245b_row35_col0, #T_0245b_row36_col0, #T_0245b_row37_col0, #T_0245b_row38_col0, #T_0245b_row39_col0, #T_0245b_row40_col0, #T_0245b_row41_col0, #T_0245b_row42_col0, #T_0245b_row43_col0, #T_0245b_row44_col0, #T_0245b_row45_col0, #T_0245b_row46_col0, #T_0245b_row47_col0, #T_0245b_row48_col0, #T_0245b_row49_col0, #T_0245b_row50_col0, #T_0245b_row51_col0, #T_0245b_row52_col0, #T_0245b_row53_col0, #T_0245b_row54_col0, #T_0245b_row55_col0, #T_0245b_row56_col0, #T_0245b_row57_col0, #T_0245b_row58_col0, #T_0245b_row59_col0, #T_0245b_row60_col0, #T_0245b_row61_col0, #T_0245b_row62_col0, #T_0245b_row63_col0, #T_0245b_row64_col0, #T_0245b_row65_col0, #T_0245b_row66_col0, #T_0245b_row67_col0, #T_0245b_row68_col0, #T_0245b_row69_col0, #T_0245b_row70_col0, #T_0245b_row71_col0, #T_0245b_row72_col0, #T_0245b_row73_col0, #T_0245b_row74_col0, #T_0245b_row75_col0, #T_0245b_row76_col0, #T_0245b_row77_col0, #T_0245b_row78_col0, #T_0245b_row79_col0, #T_0245b_row80_col0, #T_0245b_row81_col0, #T_0245b_row82_col0, #T_0245b_row83_col0, #T_0245b_row84_col0, #T_0245b_row85_col0, #T_0245b_row86_col0, #T_0245b_row87_col0, #T_0245b_row88_col0, #T_0245b_row89_col0, #T_0245b_row90_col0, #T_0245b_row91_col0, #T_0245b_row92_col0, #T_0245b_row93_col0, #T_0245b_row94_col0, #T_0245b_row95_col0, #T_0245b_row96_col0, #T_0245b_row97_col0, #T_0245b_row98_col0, #T_0245b_row99_col0, #T_0245b_row100_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_0245b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0245b_level0_col0" class="col_heading level0 col0" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0245b_level0_row0" class="row_heading level0 row0" >cbcl_q165797_attacks/threatens/bullies</th>
#       <td id="T_0245b_row0_col0" class="data row0 col0" >0.615500</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row1" class="row_heading level0 row1" >cbcl_q21106_destroys</th>
#       <td id="T_0245b_row1_col0" class="data row1 col0" >0.529500</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row2" class="row_heading level0 row2" >Gets in many fights</th>
#       <td id="T_0245b_row2_col0" class="data row2 col0" >0.525400</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row3" class="row_heading level0 row3" >Screams a lot</th>
#       <td id="T_0245b_row3_col0" class="data row3 col0" >0.483300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row4" class="row_heading level0 row4" >Swearing or obscene language</th>
#       <td id="T_0245b_row4_col0" class="data row4 col0" >0.474600</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row5" class="row_heading level0 row5" >cbcl_q222328_disobeys_rules</th>
#       <td id="T_0245b_row5_col0" class="data row5 col0" >0.467700</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row6" class="row_heading level0 row6" >Temper tantrums or hot temper</th>
#       <td id="T_0245b_row6_col0" class="data row6 col0" >0.460700</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row7" class="row_heading level0 row7" >cbcl_q2548_peer_problems</th>
#       <td id="T_0245b_row7_col0" class="data row7 col0" >0.438300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row8" class="row_heading level0 row8" >Doesn't seem to feel guilty after misbehaving</th>
#       <td id="T_0245b_row8_col0" class="data row8 col0" >0.433100</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row9" class="row_heading level0 row9" >Feels others are out to get them</th>
#       <td id="T_0245b_row9_col0" class="data row9 col0" >0.415300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row10" class="row_heading level0 row10" >Feels or complains that no one loves them</th>
#       <td id="T_0245b_row10_col0" class="data row10 col0" >0.414600</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row11" class="row_heading level0 row11" >cbcl_q8182_steals</th>
#       <td id="T_0245b_row11_col0" class="data row11 col0" >0.413500</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row12" class="row_heading level0 row12" >Sudden changes in mood or feelings</th>
#       <td id="T_0245b_row12_col0" class="data row12 col0" >0.413300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row13" class="row_heading level0 row13" >Teases a lot</th>
#       <td id="T_0245b_row13_col0" class="data row13 col0" >0.407700</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row14" class="row_heading level0 row14" >Suspicious</th>
#       <td id="T_0245b_row14_col0" class="data row14 col0" >0.399600</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row15" class="row_heading level0 row15" >Lying or cheating</th>
#       <td id="T_0245b_row15_col0" class="data row15 col0" >0.382100</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row16" class="row_heading level0 row16" >Stubborn, sullen, or irritable</th>
#       <td id="T_0245b_row16_col0" class="data row16 col0" >0.377700</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row17" class="row_heading level0 row17" >Argues a lot</th>
#       <td id="T_0245b_row17_col0" class="data row17 col0" >0.371800</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row18" class="row_heading level0 row18" >Sulks a lot</th>
#       <td id="T_0245b_row18_col0" class="data row18 col0" >0.360500</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row19" class="row_heading level0 row19" >Unhappy, sad, or depressed</th>
#       <td id="T_0245b_row19_col0" class="data row19 col0" >0.347700</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row20" class="row_heading level0 row20" >Easily jealous</th>
#       <td id="T_0245b_row20_col0" class="data row20 col0" >0.347100</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row21" class="row_heading level0 row21" >Runs away from home</th>
#       <td id="T_0245b_row21_col0" class="data row21 col0" >0.340600</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row22" class="row_heading level0 row22" >There is very little they enjoy</th>
#       <td id="T_0245b_row22_col0" class="data row22 col0" >0.339400</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row23" class="row_heading level0 row23" >Cruel to animals</th>
#       <td id="T_0245b_row23_col0" class="data row23 col0" >0.338300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row24" class="row_heading level0 row24" >Talks about killing self</th>
#       <td id="T_0245b_row24_col0" class="data row24 col0" >0.329000</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row25" class="row_heading level0 row25" >Strange behavior</th>
#       <td id="T_0245b_row25_col0" class="data row25 col0" >0.314100</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row26" class="row_heading level0 row26" >Impulsive or acts without thinking</th>
#       <td id="T_0245b_row26_col0" class="data row26 col0" >0.307100</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row27" class="row_heading level0 row27" >Hangs around with others who get in trouble</th>
#       <td id="T_0245b_row27_col0" class="data row27 col0" >0.292300</td>
#     </tr>
#     <tr>
#       <th id="T_0245b_level0_row28" class="row_heading level0 row28" >Secretive, keeps things to self</th>
#       <td id="T_0245b_row28_col0" class="data row28 col0" >0.287300</td>
#     </tr>
#     <tr>
#       <th id="T_0

# %%
# 5 factors
factor_scores5, loadings_5 = get_EFA_structure(baseline_data, 5, 'varimax', run_again = False)
loadings_5.rename(index=abcd, inplace=True)
styler5_1 = pd.DataFrame(loadings_5[0])
styler5_1.sort_values(by = 0,ascending=False, inplace= True)
styler5_1.round(4).style.applymap(color) # Externalizing (Antagonistic)

styler5_2 = pd.DataFrame(loadings_5[1])
styler5_2.sort_values(by = 1,ascending=False, inplace= True)
styler5_2.round(4).style.applymap(color) # Externalizing (Disinhibited)

styler5_3 = pd.DataFrame(loadings_5[2])
styler5_3.sort_values(by = 2,ascending=False, inplace= True)
styler5_3.round(4).style.applymap(color) # Neurodevelopmental & Detachment

styler5_4 = pd.DataFrame(loadings_5[3])
styler5_4.sort_values(by = 3,ascending=False, inplace= True)
styler5_4.round(4).style.applymap(color) # Internalizing

styler5_5 = pd.DataFrame(loadings_5[4])
styler5_5.sort_values(by = 4,ascending=False, inplace= True)
styler5_5.round(4).style.applymap(color) # Somatoform
# Out:
# <style type="text/css">
# #T_c3927_row0_col0, #T_c3927_row1_col0, #T_c3927_row2_col0 {
#   background-color: #2ecc71;
# }
# #T_c3927_row3_col0, #T_c3927_row4_col0, #T_c3927_row5_col0 {
#   background-color: #f1c40f;
# }
# #T_c3927_row6_col0, #T_c3927_row7_col0, #T_c3927_row8_col0, #T_c3927_row9_col0, #T_c3927_row10_col0, #T_c3927_row11_col0, #T_c3927_row12_col0, #T_c3927_row13_col0, #T_c3927_row14_col0, #T_c3927_row15_col0, #T_c3927_row16_col0, #T_c3927_row17_col0, #T_c3927_row18_col0, #T_c3927_row19_col0, #T_c3927_row20_col0, #T_c3927_row21_col0, #T_c3927_row22_col0, #T_c3927_row23_col0, #T_c3927_row24_col0, #T_c3927_row25_col0, #T_c3927_row26_col0, #T_c3927_row27_col0, #T_c3927_row28_col0, #T_c3927_row29_col0, #T_c3927_row30_col0, #T_c3927_row31_col0, #T_c3927_row32_col0, #T_c3927_row33_col0, #T_c3927_row34_col0, #T_c3927_row35_col0, #T_c3927_row36_col0, #T_c3927_row37_col0, #T_c3927_row38_col0, #T_c3927_row39_col0, #T_c3927_row40_col0, #T_c3927_row41_col0, #T_c3927_row42_col0, #T_c3927_row43_col0, #T_c3927_row44_col0, #T_c3927_row45_col0, #T_c3927_row46_col0, #T_c3927_row47_col0, #T_c3927_row48_col0, #T_c3927_row49_col0, #T_c3927_row50_col0, #T_c3927_row51_col0, #T_c3927_row52_col0, #T_c3927_row53_col0, #T_c3927_row54_col0, #T_c3927_row55_col0, #T_c3927_row56_col0, #T_c3927_row57_col0, #T_c3927_row58_col0, #T_c3927_row59_col0, #T_c3927_row60_col0, #T_c3927_row61_col0, #T_c3927_row62_col0, #T_c3927_row63_col0, #T_c3927_row64_col0, #T_c3927_row65_col0, #T_c3927_row66_col0, #T_c3927_row67_col0, #T_c3927_row68_col0, #T_c3927_row69_col0, #T_c3927_row70_col0, #T_c3927_row71_col0, #T_c3927_row72_col0, #T_c3927_row73_col0, #T_c3927_row74_col0, #T_c3927_row75_col0, #T_c3927_row76_col0, #T_c3927_row77_col0, #T_c3927_row78_col0, #T_c3927_row79_col0, #T_c3927_row80_col0, #T_c3927_row81_col0, #T_c3927_row82_col0, #T_c3927_row83_col0, #T_c3927_row84_col0, #T_c3927_row85_col0, #T_c3927_row86_col0, #T_c3927_row87_col0, #T_c3927_row88_col0, #T_c3927_row89_col0, #T_c3927_row90_col0, #T_c3927_row91_col0, #T_c3927_row92_col0, #T_c3927_row93_col0, #T_c3927_row94_col0, #T_c3927_row95_col0, #T_c3927_row96_col0, #T_c3927_row97_col0, #T_c3927_row98_col0, #T_c3927_row99_col0, #T_c3927_row100_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_c3927">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3927_level0_col0" class="col_heading level0 col0" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3927_level0_row0" class="row_heading level0 row0" >cbcl_q56cf_stomach_issues</th>
#       <td id="T_c3927_row0_col0" class="data row0 col0" >0.594300</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row1" class="row_heading level0 row1" >Aches or pains (not stomach or headaches)</th>
#       <td id="T_c3927_row1_col0" class="data row1 col0" >0.518100</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row2" class="row_heading level0 row2" >Headaches</th>
#       <td id="T_c3927_row2_col0" class="data row2 col0" >0.504700</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row3" class="row_heading level0 row3" >Vomiting, throwing up</th>
#       <td id="T_c3927_row3_col0" class="data row3 col0" >0.440300</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row4" class="row_heading level0 row4" >Feels dizzy or lightheaded</th>
#       <td id="T_c3927_row4_col0" class="data row4 col0" >0.423700</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row5" class="row_heading level0 row5" >Nightmares</th>
#       <td id="T_c3927_row5_col0" class="data row5 col0" >0.350300</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row6" class="row_heading level0 row6" >Rashes or other skin problems</th>
#       <td id="T_c3927_row6_col0" class="data row6 col0" >0.339400</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row7" class="row_heading level0 row7" >Other (physical problems without known physical cause)</th>
#       <td id="T_c3927_row7_col0" class="data row7 col0" >0.336000</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row8" class="row_heading level0 row8" >Talks or walks in sleep</th>
#       <td id="T_c3927_row8_col0" class="data row8 col0" >0.327300</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row9" class="row_heading level0 row9" >Gets hurt a lot, accident prone</th>
#       <td id="T_c3927_row9_col0" class="data row9 col0" >0.308200</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row10" class="row_heading level0 row10" >Constipated, doesn't move bowels</th>
#       <td id="T_c3927_row10_col0" class="data row10 col0" >0.294400</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row11" class="row_heading level0 row11" >Worries</th>
#       <td id="T_c3927_row11_col0" class="data row11 col0" >0.283900</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row12" class="row_heading level0 row12" >Trouble sleeping</th>
#       <td id="T_c3927_row12_col0" class="data row12 col0" >0.272000</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row13" class="row_heading level0 row13" >Overtired without good reason</th>
#       <td id="T_c3927_row13_col0" class="data row13 col0" >0.248500</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row14" class="row_heading level0 row14" >Problems with eyes (not if corrected by glasses) </th>
#       <td id="T_c3927_row14_col0" class="data row14 col0" >0.241800</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row15" class="row_heading level0 row15" >Underactive, slow moving, or lacks energy</th>
#       <td id="T_c3927_row15_col0" class="data row15 col0" >0.241000</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row16" class="row_heading level0 row16" >Feels too guilty</th>
#       <td id="T_c3927_row16_col0" class="data row16 col0" >0.229100</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row17" class="row_heading level0 row17" >Poorly coordinated or clumsy</th>
#       <td id="T_c3927_row17_col0" class="data row17 col0" >0.228400</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row18" class="row_heading level0 row18" >Too fearful or anxious</th>
#       <td id="T_c3927_row18_col0" class="data row18 col0" >0.220600</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row19" class="row_heading level0 row19" >Talks too much</th>
#       <td id="T_c3927_row19_col0" class="data row19 col0" >0.204900</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row20" class="row_heading level0 row20" >Fears certain animals, situations, or places, other than school</th>
#       <td id="T_c3927_row20_col0" class="data row20 col0" >0.196200</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row21" class="row_heading level0 row21" >Nervous, highstrung, or tense</th>
#       <td id="T_c3927_row21_col0" class="data row21 col0" >0.183400</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row22" class="row_heading level0 row22" >cbcl_q5355_weight_problems</th>
#       <td id="T_c3927_row22_col0" class="data row22 col0" >0.182700</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row23" class="row_heading level0 row23" >Self-conscious or easily embarrassed</th>
#       <td id="T_c3927_row23_col0" class="data row23 col0" >0.180400</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row24" class="row_heading level0 row24" >Sleeps less than most kids</th>
#       <td id="T_c3927_row24_col0" class="data row24 col0" >0.178100</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row25" class="row_heading level0 row25" >cbcl_q4070_hallucinaitons</th>
#       <td id="T_c3927_row25_col0" class="data row25 col0" >0.173200</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row26" class="row_heading level0 row26" >Unusually loud</th>
#       <td id="T_c3927_row26_col0" class="data row26 col0" >0.167300</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row27" class="row_heading level0 row27" >Prefers being with older kids</th>
#       <td id="T_c3927_row27_col0" class="data row27 col0" >0.153700</td>
#     </tr>
#     <tr>
#       <th id="T_c3927_level0_row28" class="row_heading level0 row28" >Stores up too many things they don't need</th>
#       <td

# %%
# 6 factors
factor_scores6, loadings_6 = get_EFA_structure(baseline_data, 6, 'varimax', run_again = False)
loadings_6.rename(index=abcd, inplace=True)
styler6_1 = pd.DataFrame(loadings_6[0])
styler6_1.sort_values(by = 0,ascending=False, inplace= True)
styler6_1.round(4).style.applymap(color) # Externalizing (Antagonistic)

styler6_2 = pd.DataFrame(loadings_6[1])
styler6_2.sort_values(by = 1,ascending=False, inplace= True)
styler6_2.round(4).style.applymap(color) # Internalizing

styler6_3 = pd.DataFrame(loadings_6[2])
styler6_3.sort_values(by = 2,ascending=False, inplace= True)
styler6_3.round(4).style.applymap(color) # Neurodevelopmental

styler6_4 = pd.DataFrame(loadings_6[3])
styler6_4.sort_values(by = 3,ascending=False, inplace= True)
styler6_4.round(4).style.applymap(color) # Detachment

styler6_5 = pd.DataFrame(loadings_6[4])
styler6_5.sort_values(by = 4,ascending=False, inplace= True)
styler6_5.round(4).style.applymap(color) # Somatoform

styler6_6 = pd.DataFrame(loadings_6[5])
styler6_6.sort_values(by = 5,ascending=False, inplace= True)
styler6_6.round(4).style.applymap(color) # Externalizing (Disinhibited)
# Out:
# <style type="text/css">
# #T_d0470_row0_col0, #T_d0470_row1_col0, #T_d0470_row2_col0, #T_d0470_row3_col0, #T_d0470_row4_col0, #T_d0470_row5_col0, #T_d0470_row6_col0, #T_d0470_row7_col0, #T_d0470_row8_col0 {
#   background-color: #f1c40f;
# }
# #T_d0470_row9_col0, #T_d0470_row10_col0, #T_d0470_row11_col0, #T_d0470_row12_col0, #T_d0470_row13_col0, #T_d0470_row14_col0, #T_d0470_row15_col0, #T_d0470_row16_col0, #T_d0470_row17_col0, #T_d0470_row18_col0, #T_d0470_row19_col0, #T_d0470_row20_col0, #T_d0470_row21_col0, #T_d0470_row22_col0, #T_d0470_row23_col0, #T_d0470_row24_col0, #T_d0470_row25_col0, #T_d0470_row26_col0, #T_d0470_row27_col0, #T_d0470_row28_col0, #T_d0470_row29_col0, #T_d0470_row30_col0, #T_d0470_row31_col0, #T_d0470_row32_col0, #T_d0470_row33_col0, #T_d0470_row34_col0, #T_d0470_row35_col0, #T_d0470_row36_col0, #T_d0470_row37_col0, #T_d0470_row38_col0, #T_d0470_row39_col0, #T_d0470_row40_col0, #T_d0470_row41_col0, #T_d0470_row42_col0, #T_d0470_row43_col0, #T_d0470_row44_col0, #T_d0470_row45_col0, #T_d0470_row46_col0, #T_d0470_row47_col0, #T_d0470_row48_col0, #T_d0470_row49_col0, #T_d0470_row50_col0, #T_d0470_row51_col0, #T_d0470_row52_col0, #T_d0470_row53_col0, #T_d0470_row54_col0, #T_d0470_row55_col0, #T_d0470_row56_col0, #T_d0470_row57_col0, #T_d0470_row58_col0, #T_d0470_row59_col0, #T_d0470_row60_col0, #T_d0470_row61_col0, #T_d0470_row62_col0, #T_d0470_row63_col0, #T_d0470_row64_col0, #T_d0470_row65_col0, #T_d0470_row66_col0, #T_d0470_row67_col0, #T_d0470_row68_col0, #T_d0470_row69_col0, #T_d0470_row70_col0, #T_d0470_row71_col0, #T_d0470_row72_col0, #T_d0470_row73_col0, #T_d0470_row74_col0, #T_d0470_row75_col0, #T_d0470_row76_col0, #T_d0470_row77_col0, #T_d0470_row78_col0, #T_d0470_row79_col0, #T_d0470_row80_col0, #T_d0470_row81_col0, #T_d0470_row82_col0, #T_d0470_row83_col0, #T_d0470_row84_col0, #T_d0470_row85_col0, #T_d0470_row86_col0, #T_d0470_row87_col0, #T_d0470_row88_col0, #T_d0470_row89_col0, #T_d0470_row90_col0, #T_d0470_row91_col0, #T_d0470_row92_col0, #T_d0470_row93_col0, #T_d0470_row94_col0, #T_d0470_row95_col0, #T_d0470_row96_col0, #T_d0470_row97_col0, #T_d0470_row98_col0, #T_d0470_row99_col0, #T_d0470_row100_col0 {
#   background-color: white;
# }
# </style>
# <table id="T_d0470">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0470_level0_col0" class="col_heading level0 col0" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0470_level0_row0" class="row_heading level0 row0" >Gets in many fights</th>
#       <td id="T_d0470_row0_col0" class="data row0 col0" >0.467000</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row1" class="row_heading level0 row1" >cbcl_q8182_steals</th>
#       <td id="T_d0470_row1_col0" class="data row1 col0" >0.457900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row2" class="row_heading level0 row2" >cbcl_q165797_attacks/threatens/bullies</th>
#       <td id="T_d0470_row2_col0" class="data row2 col0" >0.445700</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row3" class="row_heading level0 row3" >cbcl_q21106_destroys</th>
#       <td id="T_d0470_row3_col0" class="data row3 col0" >0.428700</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row4" class="row_heading level0 row4" >Runs away from home</th>
#       <td id="T_d0470_row4_col0" class="data row4 col0" >0.424900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row5" class="row_heading level0 row5" >Thinks about sex too much</th>
#       <td id="T_d0470_row5_col0" class="data row5 col0" >0.423700</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row6" class="row_heading level0 row6" >Swearing or obscene language</th>
#       <td id="T_d0470_row6_col0" class="data row6 col0" >0.365800</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row7" class="row_heading level0 row7" >Strange behavior</th>
#       <td id="T_d0470_row7_col0" class="data row7 col0" >0.363500</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row8" class="row_heading level0 row8" >Deliberately harms self or attempts suicide</th>
#       <td id="T_d0470_row8_col0" class="data row8 col0" >0.353300</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row9" class="row_heading level0 row9" >Plays with own sex parts in public</th>
#       <td id="T_d0470_row9_col0" class="data row9 col0" >0.347100</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row10" class="row_heading level0 row10" >Talks about killing self</th>
#       <td id="T_d0470_row10_col0" class="data row10 col0" >0.345900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row11" class="row_heading level0 row11" >Plays with own sex parts too much</th>
#       <td id="T_d0470_row11_col0" class="data row11 col0" >0.343900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row12" class="row_heading level0 row12" >Cruel to animals</th>
#       <td id="T_d0470_row12_col0" class="data row12 col0" >0.338700</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row13" class="row_heading level0 row13" >cbcl_q2548_peer_problems</th>
#       <td id="T_d0470_row13_col0" class="data row13 col0" >0.333100</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row14" class="row_heading level0 row14" >Sets fires</th>
#       <td id="T_d0470_row14_col0" class="data row14 col0" >0.312900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row15" class="row_heading level0 row15" >Feels others are out to get them</th>
#       <td id="T_d0470_row15_col0" class="data row15 col0" >0.287700</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row16" class="row_heading level0 row16" >cbcl_q4070_hallucinaitons</th>
#       <td id="T_d0470_row16_col0" class="data row16 col0" >0.267100</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row17" class="row_heading level0 row17" >Suspicious</th>
#       <td id="T_d0470_row17_col0" class="data row17 col0" >0.246100</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row18" class="row_heading level0 row18" >Strange ideas</th>
#       <td id="T_d0470_row18_col0" class="data row18 col0" >0.245600</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row19" class="row_heading level0 row19" >Teases a lot</th>
#       <td id="T_d0470_row19_col0" class="data row19 col0" >0.242600</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row20" class="row_heading level0 row20" >Hangs around with others who get in trouble</th>
#       <td id="T_d0470_row20_col0" class="data row20 col0" >0.240600</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row21" class="row_heading level0 row21" >Gets teased a lot</th>
#       <td id="T_d0470_row21_col0" class="data row21 col0" >0.236600</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row22" class="row_heading level0 row22" >Screams a lot</th>
#       <td id="T_d0470_row22_col0" class="data row22 col0" >0.219500</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row23" class="row_heading level0 row23" >Repeats certain acts over and over; compulsions</th>
#       <td id="T_d0470_row23_col0" class="data row23 col0" >0.218800</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row24" class="row_heading level0 row24" >Fears going to school</th>
#       <td id="T_d0470_row24_col0" class="data row24 col0" >0.215900</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row25" class="row_heading level0 row25" >cbcl_q222328_disobeys_rules</th>
#       <td id="T_d0470_row25_col0" class="data row25 col0" >0.195400</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row26" class="row_heading level0 row26" >Lying or cheating</th>
#       <td id="T_d0470_row26_col0" class="data row26 col0" >0.189200</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row27" class="row_heading level0 row27" >Doesn't seem to feel guilty after misbehaving</th>
#       <td id="T_d0470_row27_col0" class="data row27 col0" >0.179300</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row28" class="row_heading level0 row28" >Impulsive or acts without thinking</th>
#       <td id="T_d0470_row28_col0" class="data row28 col0" >0.175800</td>
#     </tr>
#     <tr>
#       <th id="T_d0470_level0_row29" clas

# %%
# create the labels for the different factor solutions 
name_dict = {
    '1': ['P-Factor'],
    '2': ['Broad Extern.','Broad Intern.'],
    '3': ['Broad Neurodev.','Broad Intern.','Broad Extern.'],
    '4': ['Antagonistic Extern.','Internalizing','Neurodev.','Disinhibited Extern.'],
    '5': ['Antagonistic Extern.','Disinhibited Extern.','Neurodev.','Internalizing','Somatoform'],
    '6':['Antagonistic Extern.','Internalizing','Neurodev.','Detachment','Somatoform','Disinhibited Extern.']
}

# %%
# extract the factors successively and get the correlation of factor scores
factor_scores_dict, corr_dict = factor_extract(baseline_data, 6, 'varimax')

# %%
# plot the hierarchical extraction
plot_hierarchy(corr_dict,name_dict,threshold=.4, save_as = 'final_results/Baseline_Hierarchy.png') # 65

# %%
corr_dict
# Out:
# {'factor_1factor_2': array([[0.71338028, 0.70077713]]),
#  'factor_2factor_3': array([[ 0.429308  , -0.09632315,  0.8980071 ],
#         [ 0.32933003,  0.94253216, -0.05634288]]),
#  'factor_3factor_4': array([[ 0.66669175, -0.01060052,  0.71751501, -0.20134357],
#         [-0.1179564 ,  0.97541216,  0.15356249,  0.10521567],
#         [ 0.41929026, -0.02429263, -0.13823002,  0.89692919]]),
#  'factor_4factor_5': array([[ 0.94132862, -0.09708261,  0.1756576 , -0.16422758,  0.21592403],
#         [ 0.04188297, -0.17558905,  0.0058024 ,  0.89274868,  0.41275647],
#         [-0.18553885,  0.20066356,  0.95508664, -0.01071563,  0.11396879],
#         [ 0.22079604,  0.89032012, -0.11037587,  0.28399146, -0.25636737]]),
#  'factor_5factor_6': array([[ 0.86957746,  0.07470494,  0.34578792, -0.33238949,  0.01726862,
#          -0.08870108],
#         [ 0.3041847 , -0.23169899, -0.17199644,  0.34321269,  0.04805337,
#           0.83905228],
#         [-0.18472503, -0.05042979,  0.88859348,  0.40970734, -0.0314146 ,
#           0.06947614],
#         [ 0.16119215,  0.8486443 , -0.13727913,  0.48203169, -0.01275442,
#          -0.04858326],
#         [-0.10065723,  0.12474127,  0.07418063, -0.13021677,  0.97172964,
#           0.08349348]])}
